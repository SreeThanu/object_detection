# %% [markdown]
# # Data Preprocessing
#
# This notebook handles data preprocessing for the VOC dataset.

# %%
import sys
from pathlib import Path

# Add parent directory to path
sys.path.append(str(Path().resolve().parent))

from src.preprocessing import prepare_data, get_data_loaders, VOCDataset, get_transforms
from config.config import VOC_IMAGES_DIR, VOC_ANNOTATIONS_DIR

# %% [markdown]
# ## Check Data Structure

# %%
# Prepare and validate data
stats = prepare_data()
print(f"\nData Statistics:")
for key, value in stats.items():
    print(f"  {key}: {value}")

# %% [markdown]
# ## Create Data Loaders

# %%
# Create data loaders
train_loader, val_loader = get_data_loaders(batch_size=4, num_workers=2)

print(f"Train batches: {len(train_loader)}")
print(f"Validation batches: {len(val_loader)}")

# %% [markdown]
# ## Inspect Sample Data

# %%
# Load a sample batch
images, targets = next(iter(train_loader))

print(f"Batch size: {len(images)}")
print(f"Image shape: {images[0].shape}")
print(f"\nFirst image targets:")
print(f"  Number of boxes: {len(targets[0]['boxes'])}")
print(f"  Labels: {targets[0]['labels']}")
print(f"  Boxes shape: {targets[0]['boxes'].shape}")

# %% [markdown]
# ## Create Dataset Instances

# %%
# Create dataset instances for visualization
train_dataset = VOCDataset(split='train', transform=get_transforms(train=False))
val_dataset = VOCDataset(split='val', transform=get_transforms(train=False))

print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
